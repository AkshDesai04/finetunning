# %%
print("Starting")
# !nvidia-smi
# Out:
# Starting
# Mon Jan  5 10:31:01 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# Install Unsloth + training stack
# !pip install --upgrade unsloth bitsandbytes accelerate xformers datasets peft trl sentencepiece protobuf PyPDF2
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.12/dist-packages (2026.1.1)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (1.12.0)
# Requirement already satisfied: xformers in /usr/local/lib/python3.12/dist-packages (0.0.33.post2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.3.0)
# Collecting datasets
#   Using cached datasets-4.4.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.0)
# Requirement already satisfied: trl in /usr/local/lib/python3.12/dist-packages (0.24.0)
# Collecting trl
#   Using cached trl-0.26.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (6.33.2)
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: unsloth_zoo>=2026.1.1 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2026.1.1)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from unsloth) (25.0)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.9.1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.24.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from unsloth) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: tyro in /usr/local/lib/python3.12/dist-packages (from unsloth) (1.0.3)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (3.5.1)
# Requirement already satisfied: huggingface_hub>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.36.0)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.12/dist-packages (from unsloth) (0.36.0)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3 in /usr/local/lib/python3.12/dist-packages (from unsloth) (4.57.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate) (6.0.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.0->unsloth) (1.13.1.3)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.13.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (4.12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.34.0->unsloth) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth) (0.22.1)
# Requirement already satisfied: torchao>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.1->unsloth) (0.15.0)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.1->unsloth) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.1->unsloth) (11.3.0)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from unsloth_zoo>=2026.1.1->unsloth) (0.20.0)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.12/dist-packages (from diffusers->unsloth) (8.7.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from tyro->unsloth) (4.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.3)

# %%
import unsloth
import torch
import PyPDF2
from datasets import Dataset
from unsloth import FastLanguageModel
from trl import SFTTrainer
from transformers import TrainingArguments
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
# Confirm installation
print("Unsloth:", unsloth.__version__, "CUDA:", torch.cuda.is_available())
# Out:
# Unsloth: 2026.1.1 CUDA: True

# %% [markdown]
# # Make a folder named `books` and add pdf files to it

# %%
import PyPDF2
import os

books_dir = "./books/"
text_chunks = []

if not os.path.exists(books_dir):
    print(f"Error: Directory {books_dir} does not exist.")
else:
    # Iterate through all files in the directory
    for filename in os.listdir(books_dir):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(books_dir, filename)
            print(f"Processing: {filename}...")

            try:
                with open(pdf_path, "rb") as f:
                    reader = PyPDF2.PdfReader(f)
                    for page in reader.pages:
                        text = page.extract_text()
                        if text:
                            text_chunks.append(text)
                print(f" - Completed {filename}")

            except PyPDF2.errors.PdfReadError:
                print(f" - Error: {filename} is corrupted or incomplete.")
            except Exception as e:
                print(f" - An error occurred with {filename}: {e}")

print(f"\nTotal extracted pages from all files: {len(text_chunks)}")
# Out:
# Processing: cuda-programming.pdf...
#  - Completed cuda-programming.pdf
# Processing: cudabook.pdf...
#  - Completed cudabook.pdf
# Processing: CUDA_C_Programming_Guide.pdf...
#  - Completed CUDA_C_Programming_Guide.pdf
# Processing: cuda_by_example.book.pdf...
#  - Completed cuda_by_example.book.pdf
#
# Total extracted pages from all files: 1700

# %%
# Convert pages to instruction format
data = []
for i, page in enumerate(text_chunks):
    data.append({
        "input": "",             # No explicit prompt
        "output": page.strip()
    })

dataset = Dataset.from_list(data)
dataset = dataset.train_test_split(test_size=0.05)
dataset["train"][0]
# Out:
# {'input': '',
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=MODEL_NAME,
    max_seq_length=MAX_SEQ_LEN,
    dtype=None,
    load_in_4bit=False,      # QLoRA quantized base
)
# Out:
# ==((====))==  Unsloth 2026.1.1: Fast Llama patching. Transformers: 4.57.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.9.1+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.5.1
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.33.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
LORA_R = 16
LORA_ALPHA = 16
TARGET_MODULES = [
    "q_proj", "k_proj", "v_proj", "o_proj",
    "gate_proj", "up_proj", "down_proj"
]

model = FastLanguageModel.get_peft_model(
    model,
    r=LORA_R,
    target_modules=TARGET_MODULES,
    lora_alpha=LORA_ALPHA  # CHANGED: 'alpha' -> 'lora_alpha'
)
# Out:
# Unsloth: Already have LoRA adapters! We shall skip this step.

# %%
# 1. Define the formatting function
def formatting_prompts_func(examples):
    # This handles the "input" and "output" columns you created earlier
    outputs = examples["output"]

    texts = []
    for output in outputs:
        # Since your 'input' is empty, we just feed the text content (output)
        # If you wanted a specific prompt format, you would add it here.
        text = f"{output}"
        texts.append(text)
    return texts

# 2. Setup Training Arguments (Same as before)
train_args = TrainingArguments(
    output_dir="./fine_tuned_llama3.2_book",
    per_device_train_batch_size=1,
    gradient_accumulation_steps=8,
    learning_rate=1e-4,
    fp16=True,

    num_train_epochs=50,          # Stops after 1 full pass of dataset
    save_strategy="epoch",       # Save only at the end of each epoch
    logging_strategy="epoch",    # Log metrics only at the end of each epoch
)

# 3. Initialize Trainer with the formatting function
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset["train"],
    eval_dataset=dataset["test"],
    peft_config=None,
    tokenizer=tokenizer,
    args=train_args,
    formatting_func=formatting_prompts_func, # <--- ADDED THIS LINE
)
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=4):   0%|          | 0/1615 [00:00<?, ? examples/s]
# Unsloth: Tokenizing ["text"] (num_proc=4):   0%|          | 0/85 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,615 | Num Epochs = 50 | Total steps = 10,100
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 8
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 8 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20260105_105927-100zpcmw</code>
# Syncing run <strong><a href='https://wandb.ai/aksh-d-4002-charusat-university/huggingface/runs/100zpcmw' target="_blank">deft-universe-18</a></strong> to <a href='https://wandb.ai/aksh-d-4002-charusat-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aksh-d-4002-charusat-university/huggingface' target="_blank">https://wandb.ai/aksh-d-4002-charusat-university/huggingface</a>
#  View run at <a href='https://wandb.ai/aksh-d-4002-charusat-university/huggingface/runs/100zpcmw' target="_blank">https://wandb.ai/aksh-d-4002-charusat-university/huggingface/runs/100zpcmw</a>
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='345' max='10100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  345/10100 32:15 < 15:17:19, 0.18 it/s, Epoch 1.70/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>202</td>
#       <td>1.952300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
model.save_pretrained("./llama3.2_book_finetuned_" + num_train_epochs + "_steps")
tokenizer.save_pretrained("./llama3.2_book_finetuned_" + num_train_epochs + "_steps")
# Out:
# ('./llama3.2_book_finetuned/tokenizer_config.json',
#  './llama3.2_book_finetuned/special_tokens_map.json',
#  './llama3.2_book_finetuned/chat_template.jinja',
#  './llama3.2_book_finetuned/tokenizer.json')

# %%
# Save the full merged model (combines base model + your 115MB adapters)
model.save_pretrained_merged(
    "./llama3.2_book_finetuned_" + num_train_epochs + "_steps_FULL",
    tokenizer,
    save_method = "merged_16bit",  # Options: "merged_16bit", "merged_4bit", "lora"
)

print("Full model saved to ./llama3.2_book_finetuned_" + num_train_epochs + "_steps_FULL")
# Out:
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Unsloth: Copying 2 files from cache to `llama3.2_book_finetuned_FULL`: 100%|██████████| 2/2 [01:46<00:00, 53.00s/it]
# Successfully copied all 2 files from cache to `llama3.2_book_finetuned_FULL`
# Checking cache directory for required files...
# Cache check failed: tokenizer.model not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Unsloth: Preparing safetensor model files: 100%|██████████| 2/2 [00:00<00:00, 18078.90it/s]
# Unsloth: Merging weights into 16bit: 100%|██████████| 2/2 [02:57<00:00, 88.91s/it]
# Unsloth: Merge process complete. Saved to `/content/llama3.2_book_finetuned_FULL`
# Full model saved to ./llama3.2_book_finetuned_FULL

# %%
# !zip -r llama3.2_book_finetuned_50_steps.zip ./llama3.2_book_finetuned_50_steps_FULL
# Out:
#   adding: .config/ (stored 0%)
#   adding: .config/default_configs.db (deflated 98%)
#   adding: .config/config_sentinel (stored 0%)
#   adding: .config/.last_update_check.json (deflated 22%)
#   adding: .config/active_config (stored 0%)
#   adding: .config/.last_survey_prompt.yaml (stored 0%)
#   adding: .config/gce (stored 0%)
#   adding: .config/configurations/ (stored 0%)
#   adding: .config/configurations/config_default (deflated 15%)
#   adding: .config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db (deflated 97%)
#   adding: .config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: .config/logs/ (stored 0%)
#   adding: .config/logs/2025.12.09/ (stored 0%)
#   adding: .config/logs/2025.12.09/14.41.43.412452.log (deflated 56%)
#   adding: .config/logs/2025.12.09/14.41.42.675750.log (deflated 57%)
#   adding: .config/logs/2025.12.09/14.41.18.717681.log (deflated 58%)
#   adding: .config/logs/2025.12.09/14.41.27.893750.log (deflated 86%)
#   adding: .config/logs/2025.12.09/14.40.47.605300.log (deflated 92%)
#   adding: .config/logs/2025.12.09/14.41.33.792924.log (deflated 58%)
#   adding: huggingface_tokenizers_cache/ (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/ (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/models--unsloth--Llama-3.2-3B-Instruct/ (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/models--unsloth--Llama-3.2-3B-Instruct/3dc1faa6025cdb195c0889dd8d3d13ca26af9225.lock (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/models--unsloth--Llama-3.2-3B-Instruct/3c1d04911c269b925af977a3151c9704e990e4d0.lock (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/models--unsloth--Llama-3.2-3B-Instruct/1bad6a0f648dccdbec523ca79ba90fbcfc806af0.lock (stored 0%)
#   adding: huggingface_tokenizers_cache/.locks/models--unsloth--Llama-3.2-3B-Instruct/6b9e4e7fb171f92fd137b777cc2714bf87d11576700a1dcd7a399e7bbe39537b.lock (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/.no_exist/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/.no_exist/006f5dcd1393c3add266de40994ba96225e9689d/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/.no_exist/006f5dcd1393c3add266de40994ba96225e9689d/added_tokens.json (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/.no_exist/006f5dcd1393c3add266de40994ba96225e9689d/tokenizer.model (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/006f5dcd1393c3add266de40994ba96225e9689d/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/006f5dcd1393c3add266de40994ba96225e9689d/tokenizer.json (deflated 85%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/006f5dcd1393c3add266de40994ba96225e9689d/special_tokens_map.json (deflated 71%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/006f5dcd1393c3add266de40994ba96225e9689d/tokenizer_config.json (deflated 94%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/snapshots/006f5dcd1393c3add266de40994ba96225e9689d/chat_template.jinja (deflated 71%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/refs/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/refs/main (deflated 3%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/blobs/ (stored 0%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/blobs/3dc1faa6025cdb195c0889dd8d3d13ca26af9225 (deflated 94%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/blobs/3c1d04911c269b925af977a3151c9704e990e4d0 (deflated 71%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/blobs/1bad6a0f648dccdbec523ca79ba90fbcfc806af0 (deflated 71%)
#   adding: huggingface_tokenizers_cache/models--unsloth--Llama-3.2-3B-Instruct/blobs/6b9e4e7fb171f92fd137b777cc2714bf87d11576700a1dcd7a399e7bbe39537b (deflated 85%)
#   adding: wandb/ (stored 0%)
#   adding: wandb/debug.log (deflated 67%)
#   adding: wandb/latest-run/ (stored 0%)
#   adding: wandb/latest-run/run-w45wy11a.wandb (deflated 75%)
#   adding: wandb/latest-run/tmp/ (stored 0%)
#   adding: wandb/latest-run/tmp/code/ (stored 0%)
#   adding: wandb/latest-run/files/ (stored 0%)
#   adding: wandb/latest-run/files/output.log (deflated 31%)
#   adding: wandb/latest-run/files/config.yaml (deflated 71%)
#   adding: wandb/latest-run/files/requirements.txt (deflated 56%)
#   adding: wandb/latest-run/files/wandb-metadata.json (deflated 44%)
#   adding: wandb/latest-run/files/wandb-summary.json (deflated 43%)
#   adding: wandb/latest-run/logs/ (stored 0%)
#   adding: wandb/latest-run/logs/debug.log (deflated 67%)
#   adding: wandb/latest-run/logs/debug-core.log (deflated 62%)
#   adding: wandb/latest-run/logs/debug-internal.log (deflated 75%)
#   adding: wandb/run-20260105_104023-w45wy11a/ (stored 0%)
#   adding: wandb/run-20260105_104023-w45wy11a/run-w45wy11a.wandb (deflated 75%)
#   adding: wandb/run-20260105_104023-w45wy11a/tmp/ (stored 0%)
#   adding: wandb/run-20260105_104023-w45wy11a/tmp/code/ (stored 0%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/ (stored 0%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/output.log (deflated 31%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/config.yaml (deflated 71%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/requirements.txt (deflated 56%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/wandb-metadata.json (deflated 44%)
#   adding: wandb/run-20260105_104023-w45wy11a/files/wandb-summary.json (deflated 43%)
#   adding: wandb/run-20260105_104023-w45wy11a/logs/ (stored 0%)
#   adding: wandb/run-20260105_104023-w45wy11a/logs/debug.log (deflated 67%)
#   adding: wandb/run-20260105_104023-w45wy11a/logs/debug-core.log (deflated 62%)
#   adding: wandb/run-20260105_104023-w45wy11a/logs/debug-internal.log (deflated 75%)
#   adding: wandb/debug-internal.log (deflated 75%)
#   adding: unsloth_compiled_cache/ (stored 0%)
#   adding: unsloth_compiled_cache/UnslothCPOTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothPPOTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothORPOTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothRLOOTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothKTOTrainer.py (deflated 79%)
#   adding: unsloth_compiled_cache/.locks/ (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothORPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothBCOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothOnlineDPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothPRMTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothCPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothNashMDTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothSFTTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothXPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothDPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothGRPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothGKDTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothRewardTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothRLOOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothKTOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/.locks/.lock.UnslothPPOTrainer.py (stored 0%)
#   adding: unsloth_compiled_cache/UnslothXPOTrainer.py (deflated 77%)
#   adding: unsloth_compiled_cache/UnslothDPOTrainer.py (deflated 78%)
#   adding: unsloth_compiled_cache/UnslothSFTTrainer.py (deflated 75%)
#   adding: unsloth_compiled_cache/__pycache__/ (stored 0%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothPRMTrainer.cpython-312.pyc (deflated 52%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothRewardTrainer.cpython-312.pyc (deflated 53%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothSFTTrainer.cpython-312.pyc (deflated 54%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothOnlineDPOTrainer.cpython-312.pyc (deflated 55%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothRLOOTrainer.cpython-312.pyc (deflated 57%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothPPOTrainer.cpython-312.pyc (deflated 54%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothCPOTrainer.cpython-312.pyc (deflated 55%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothGKDTrainer.cpython-312.pyc (deflated 53%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothBCOTrainer.cpython-312.pyc (deflated 56%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothGRPOTrainer.cpython-312.pyc (deflated 58%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothORPOTrainer.cpython-312.pyc (deflated 54%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothDPOTrainer.cpython-312.pyc (deflated 58%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothKTOTrainer.cpython-312.pyc (deflated 57%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothXPOTrainer.cpython-312.pyc (deflated 52%)
#   adding: unsloth_compiled_cache/__pycache__/UnslothNashMDTrainer.cpython-312.pyc (deflated 52%)
#   adding: unsloth_compiled_cache/UnslothGRPOTrainer.py (deflated 78%)
#   adding: unsloth_compiled_cache/UnslothOnlineDPOTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothPRMTrainer.py (deflated 75%)
#   adding: unsloth_compiled_cache/UnslothRewardTrainer.py (deflated 75%)
#   adding: unsloth_compiled_cache/UnslothNashMDTrainer.py (deflated 76%)
#   adding: unsloth_compiled_cache/UnslothGKDTrainer.py (deflated 75%)
#   adding: unsloth_compiled_cache/UnslothBCOTrainer.py (deflated 78%)
#   adding: llama3.2_book_finetuned/ (stored 0%)
#   adding: llama3.2_book_finetuned/tokenizer.json (deflated 85%)
#   adding: llama3.2_book_finetuned/special_tokens_map.json (deflated 71%)
#   adding: llama3.2_book_finetuned/tokenizer_config.json (deflated 96%)
#   adding: llama3.2_book_finetuned/adapter_config.json (deflated 58%)
#   adding: llama3.2_book_finetuned/chat_template.jinja (deflated 71%)
#   adding: llama3.2_book_finetuned/adapter_model.safetensors (deflated 8%)
#   adding: llama3.2_book_finetuned/README.md (deflated 65%)
#   adding: books/ (stored 0%)
#   adding: books/cuda-programming.pdf (deflated 4%)
#   adding: books/cudabook.pdf (deflated 26%)
#   adding: books/CUDA_C_Programming_Guide.pdf (deflated 6%)
#   adding: books/cuda_by_example.book.pdf (deflated 37%)
#   adding: fine_tuned_llama3.2_book/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/trainer_state.json (deflated 70%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-10/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/scheduler.pt (deflated 62%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/trainer_state.json (deflated 78%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/optimizer.pt (deflated 9%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-50/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/runs/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/runs/Jan05_10-36-22_0fb0ed89e418/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/runs/Jan05_10-36-22_0fb0ed89e418/events.out.tfevents.1767609400.0fb0ed89e418.2701.0 (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/trainer_state.json (deflated 78%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/optimizer.pt (deflated 9%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-45/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/trainer_state.json (deflated 74%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-20/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/trainer_state.json (deflated 78%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/optimizer.pt (deflated 9%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-40/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/scheduler.pt (deflated 62%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/trainer_state.json (deflated 75%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-25/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/trainer_state.json (deflated 72%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/adapter_model.safetensors (deflated 7%)
#   adding: fine_tuned_llama3.2_book/checkpoint-15/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/trainer_state.json (deflated 76%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-30/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/trainer_state.json (deflated 77%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-35/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/ (stored 0%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/scheduler.pt (deflated 61%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/trainer_state.json (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/rng_state.pth (deflated 26%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/tokenizer.json (deflated 85%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/special_tokens_map.json (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/tokenizer_config.json (deflated 96%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/optimizer.pt (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/adapter_config.json (deflated 58%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/training_args.bin (deflated 53%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/scaler.pt (deflated 64%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/chat_template.jinja (deflated 71%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/adapter_model.safetensors (deflated 8%)
#   adding: fine_tuned_llama3.2_book/checkpoint-5/README.md (deflated 65%)
#   adding: fine_tuned_llama3.2_book/README.md (deflated 43%)
#   adding: .ipynb_checkpoints/ (stored 0%)
#   adding: llama3.2_book_finetuned_FULL/ (stored 0%)
#   adding: llama3.2_book_finetuned_FULL/model-00002-of-00002.safetensors
#
#
# zip error: Interrupted (aborting)

# %% [markdown]
# # Now you can download the all.zip folder to get all the data
